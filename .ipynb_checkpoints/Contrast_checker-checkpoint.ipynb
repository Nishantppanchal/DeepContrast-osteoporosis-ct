# %%
import sqlite3
import pandas as pd

# %%
connection = sqlite3.connect(r"/nfs/MBSI/Osteoporosis/Head-CT/DB/BoneDensity_2023-01-26_final_vacuumed.db")

BMD_tbl_Image_df = pd.read_sql_query("SELECT * FROM BMD_tbl_Image", connection)
BMD_tbl_Subject_df = pd.read_sql_query("SELECT * FROM BMD_tbl_Subject", connection)
BMD_tbl_Test_df = pd.read_sql_query("SELECT * FROM BMD_tbl_Test", connection)

# %%
BMD_tbl_Test_df["ContrastBolusAgent"]
# Out:
# 0
# 1        Anonymized
# 2        Anonymized
# 3        Anonymized
# 4        Anonymized
#             ...
# 15882
# 15883
# 15884
# 15885
# 15886
# Name: ContrastBolusAgent, Length: 15887, dtype: object

# %%
db = pd.merge(left=BMD_tbl_Subject_df, right=BMD_tbl_Test_df, on="StudyInstanceUID")
db = pd.merge(left=db, right=BMD_tbl_Image_df[["SeriesInstanceUID", "SOPInstanceUID", "InstanceNumber"]], on="SeriesInstanceUID")
db = db[["SubjectID", "StudyInstanceUID", "SeriesInstanceUID", "SOPInstanceUID"]]
db["Path"] = db["SubjectID"] + "/" + db["SOPInstanceUID"] + ".dcm"
db = db.groupby(["SubjectID", "StudyInstanceUID", "SeriesInstanceUID"])["Path"].apply(list).reset_index(name="Paths")
db
# Out:
#      SubjectID                                   StudyInstanceUID  \
# 0       000001           2.4.22.7.1.0.809.31.09.3.3674842.9997348
# 1       000002           2.8.87.6.1.3.655.13.96.2.5512322.3482028
# 2       000003  2.2.608.766635.1.359.1622547801596435695451690...
# 3       000004           1.5.45.0.8.6.938.52.83.8.8919638.3879877
# 4       000005           1.8.83.7.4.9.347.00.62.3.2649351.4118139
# ...        ...                                                ...
# 2053    002073           2.9.03.4.3.0.909.42.93.2.1301046.0882547
# 2054    002074           8.4.53.9.4.3.698.94.99.3.4639681.3821970
# 2055    002075           2.1.10.5.2.7.796.94.12.3.9915496.5542016
# 2056    002076           6.7.32.9.8.3.862.33.94.7.7708353.0016191
# 2057    002077  3.5.400.580526.4.113.5.977850481.044.659966205...
#
#                                       SeriesInstanceUID  \
# 0     7.7.047.792778.6.29.007400871.46906.1494282718...
# 1     8.4.13.5.7107.1.3.1.83378.85160090820978679507...
# 2     8.6.164.245568.6.95.8200738032.6711.2222200789...
# 3     8.2.311.726762.5.22.9217994636.8301.5241719335...
# 4     9.6.841.464467.4574.5.5.1.85.5681651901.673660...
# ...                                                 ...
# 2053  8.6.445.753144.8.62.3786901830.05650.243881648...
# 2054  5.4.805.860428.7.65.2439446130.59792.483177683...
# 2055  2.7.852.918558.9.58.881702658.21645.9393837632...
# 2056  6.7.971.555090.3485.1.3.2.96.3817363671.729992...
# 2057  0.3.433.532416.4.69.1338577813.321661.78291071...
#
#                                                   Paths
# 0     [000001/0.0.245.293888.6.99.899793490.23242.58...
# 1     [000002/0.2.25.6.4580.5.5.5.53656.002989106355...
# 2     [000003/0.0.539.298793.1.29.9098886385.8398.08...
# 3     [000004/0.0.147.540316.8.98.6446798389.2642.18...
# 4     [000005/0.0.426.629185.3233.9.4.2.04.800863952...
# ...                                                 ...
# 2053  [002073/0.1.639.825144.5.44.2259705986.09934.4...
# 2054  [002074/0.1.171.657987.8.63.8492669404.50851.1...
# 2055  [002075/1.0.715.425889.4.21.531791081.47129.75...
# 2056  [002076/0.0.828.321850.7025.1.6.4.82.913749341...
# 2057  [002077/0.0.529.947175.6.80.4200332486.427197....
#
# [2058 rows x 4 columns]

# %%
display(BMD_tbl_Test_df[BMD_tbl_Test_df["StudyInstanceUID"] == "6.6.36.9.1.2.936.04.81.3.6408074.7693526"])
print(list(BMD_tbl_Test_df[BMD_tbl_Test_df["StudyInstanceUID"] == "6.6.36.9.1.2.936.04.81.3.6408074.7693526"]["SeriesInstanceUID"]))
# Out:
# Empty DataFrame
# Columns: [StudyInstanceUID, SeriesInstanceUID, SeriesDescription, SeriesNumber, SeriesDate, AcquisitionDate, ContentDate, SeriesTime, AcquisitionTime, ContentTime, Modality, ContrastBolusAgent, AcquisitionMatrix, InPlanePhaseEncodingDirection, FlipAngle, VariableFlipAngleFlag, ProtocolName, CardiacNumberOfImages, SequenceName, ScanningSequence, SequenceVariant, ScanOptions, MRAcquisitionType, SliceThickness, RepetitionTime, EchoTime, NumberOfAverages, EchoNumbers, MagneticFieldStrength, NumberOfPhaseEncodingSteps, EchoTrainLength, PercentSampling, PercentPhaseFieldOfView, PixelBandwidth, ContrastBolusVolume, OptimalTI, InstanceNumber_OptimalTI, Status, IsTestset, DICOMVolumeFolder, NIfTIVolumeFolder, LabelVolumeFolder, SliceIndex, DataFolder, DataSetFolder, DataSetFolderG]
# Index: []
#
# [0 rows x 46 columns]
# []

# %%
display(BMD_tbl_Image_df[BMD_tbl_Image_df["SeriesInstanceUID"] == "0.4.140.631377.3.59.029197734.69890.4068989577.34.9.8"])
# for seriesInstanceUID in list(BMD_tbl_Test_df[BMD_tbl_Test_df["StudyInstanceUID"] == "6.6.36.9.1.2.936.04.81.3.6408074.7693526"]["SeriesInstanceUID"]):
#     print(len(list(BMD_tbl_Image_df[BMD_tbl_Image_df["SeriesInstanceUID"] == seriesInstanceUID]["FileName"])))
# Out:
# Empty DataFrame
# Columns: [StudyInstanceUID, SeriesInstanceUID, SOPInstanceUID, InstanceNumber, TriggerTime, SpecificCharacterSet, ImageType, InstanceCreationDate, InstanceCreationTime, SOPClassUID, NominalInterval, AcquisitionMatrix, InPlanePhaseEncodingDirection, FlipAngle, VariableFlipAngleFlag, AcquisitionNumber, AnatomicalOrientationType, ImagePositionPatient, ImageOrientationPatient, Direction, FrameOfReferenceUID, SliceLocation, SamplesPerPixel, PhotometricInterpretation, Rows, Columns, PixelSpacing, BitsAllocated, BitsStored, HighBit, PixelRepresentation, SmallestImagePixelValue, LargestImagePixelValue, WindowCenter, WindowWidth, WindowCenterWidthExplanation, Selected, FileName, ArchiveFileName]
# Index: []
#
# [0 rows x 39 columns]

# %%
BMD_tbl_Test_df.columns
# Out:
# Index(['StudyInstanceUID', 'SeriesInstanceUID', 'SeriesDescription',
#        'SeriesNumber', 'SeriesDate', 'AcquisitionDate', 'ContentDate',
#        'SeriesTime', 'AcquisitionTime', 'ContentTime', 'Modality',
#        'ContrastBolusAgent', 'AcquisitionMatrix',
#        'InPlanePhaseEncodingDirection', 'FlipAngle', 'VariableFlipAngleFlag',
#        'ProtocolName', 'CardiacNumberOfImages', 'SequenceName',
#        'ScanningSequence', 'SequenceVariant', 'ScanOptions',
#        'MRAcquisitionType', 'SliceThickness', 'RepetitionTime', 'EchoTime',
#        'NumberOfAverages', 'EchoNumbers', 'MagneticFieldStrength',
#        'NumberOfPhaseEncodingSteps', 'EchoTrainLength', 'PercentSampling',
#        'PercentPhaseFieldOfView', 'PixelBandwidth', 'ContrastBolusVolume',
#        'OptimalTI', 'InstanceNumber_OptimalTI', 'Status', 'IsTestset',
#        'DICOMVolumeFolder', 'NIfTIVolumeFolder', 'LabelVolumeFolder',
#        'SliceIndex', 'DataFolder', 'DataSetFolder', 'DataSetFolderG'],
#       dtype='object')

# %%
print(len(BMD_tbl_Subject_df.index))
# Out:
# 2060

# %%
print(len(BMD_tbl_Test_df.index))
# Out:
# 2060

# %%
results_df = pd.read_csv("./test_df_with_contrast.csv")

# %%
import numpy as np
results_df[~results_df["Contrast"].isna()]
# Out:
#    Unnamed: 0                          StudyInstanceUID  \
# 0           0  9.7.95.7.1.4.836.67.70.0.6066900.1952144
#
#                                    SeriesInstanceUID  SeriesDescription  \
# 0  5.7.02.1.9072.3.2.4.27669.66325498560602137273...                NaN
#
#    SeriesNumber  SeriesDate  AcquisitionDate  ContentDate  SeriesTime  \
# 0             4       10101            10101        10101         0.0
#
#    AcquisitionTime  ...  Status IsTestset DICOMVolumeFolder  \
# 0              0.0  ...     NaN       NaN               NaN
#
#    NIfTIVolumeFolder  LabelVolumeFolder  SliceIndex  DataFolder DataSetFolder  \
# 0                NaN                NaN         NaN         NaN           NaN
#
#    DataSetFolderG  Contrast
# 0             NaN       0.0
#
# [1 rows x 48 columns]

# %%
BMD_tbl_Subject_df.j

# %%
predictions_df = pd.read_csv("test_df_with_contrast.csv")
predictions_df
# Out:
#       Unnamed: 0  SubjectID  \
# 0              0          1
# 1              1          2
# 2              2          3
# 3              3          4
# 4              4          5
# ...          ...        ...
# 2053        2053       2073
# 2054        2054       2074
# 2055        2055       2075
# 2056        2056       2076
# 2057        2057       2077
#
#                                        StudyInstanceUID  \
# 0              2.4.22.7.1.0.809.31.09.3.3674842.9997348
# 1              2.8.87.6.1.3.655.13.96.2.5512322.3482028
# 2     2.2.608.766635.1.359.1622547801596435695451690...
# 3              1.5.45.0.8.6.938.52.83.8.8919638.3879877
# 4              1.8.83.7.4.9.347.00.62.3.2649351.4118139
# ...                                                 ...
# 2053           2.9.03.4.3.0.909.42.93.2.1301046.0882547
# 2054           8.4.53.9.4.3.698.94.99.3.4639681.3821970
# 2055           2.1.10.5.2.7.796.94.12.3.9915496.5542016
# 2056           6.7.32.9.8.3.862.33.94.7.7708353.0016191
# 2057  3.5.400.580526.4.113.5.977850481.044.659966205...
#
#                                       SeriesInstanceUID  \
# 0     7.7.047.792778.6.29.007400871.46906.1494282718...
# 1     8.4.13.5.7107.1.3.1.83378.85160090820978679507...
# 2     8.6.164.245568.6.95.8200738032.6711.2222200789...
# 3     8.2.311.726762.5.22.9217994636.8301.5241719335...
# 4     9.6.841.464467.4574.5.5.1.85.5681651901.673660...
# ...                                                 ...
# 2053  8.6.445.753144.8.62.3786901830.05650.243881648...
# 2054  5.4.805.860428.7.65.2439446130.59792.483177683...
# 2055  2.7.852.918558.9.58.881702658.21645.9393837632...
# 2056  6.7.971.555090.3485.1.3.2.96.3817363671.729992...
# 2057  0.3.433.532416.4.69.1338577813.321661.78291071...
#
#                                                   Paths  Contrast
# 0     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 1     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
# 2     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 3     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 4     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
# ...                                                 ...       ...
# 2053  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 2054  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 2055  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 2056  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
# 2057  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
#
# [2058 rows x 6 columns]

# %%
print(f"Errors: {len(predictions_df[predictions_df['Contrast'] == -1].index)}\nContrast: {len(predictions_df[predictions_df['Contrast'] == 1].index)}\nNon-contrast: {len(predictions_df[predictions_df['Contrast'] == 0].index)}")
# Out:
# Errors: 875
# Contrast: 531
# Non-contrast: 652

# %%
predictions_df = pd.merge(left=predictions_df, right=BMD_tbl_Test_df[["SeriesInstanceUID", "ContrastBolusAgent"]], on="SeriesInstanceUID")
predictions_df
# Out:
#       Unnamed: 0  SubjectID  \
# 0              0          1
# 1              1          2
# 2              2          3
# 3              3          4
# 4              4          5
# ...          ...        ...
# 2053        2053       2073
# 2054        2054       2074
# 2055        2055       2075
# 2056        2056       2076
# 2057        2057       2077
#
#                                        StudyInstanceUID  \
# 0              2.4.22.7.1.0.809.31.09.3.3674842.9997348
# 1              2.8.87.6.1.3.655.13.96.2.5512322.3482028
# 2     2.2.608.766635.1.359.1622547801596435695451690...
# 3              1.5.45.0.8.6.938.52.83.8.8919638.3879877
# 4              1.8.83.7.4.9.347.00.62.3.2649351.4118139
# ...                                                 ...
# 2053           2.9.03.4.3.0.909.42.93.2.1301046.0882547
# 2054           8.4.53.9.4.3.698.94.99.3.4639681.3821970
# 2055           2.1.10.5.2.7.796.94.12.3.9915496.5542016
# 2056           6.7.32.9.8.3.862.33.94.7.7708353.0016191
# 2057  3.5.400.580526.4.113.5.977850481.044.659966205...
#
#                                       SeriesInstanceUID  \
# 0     7.7.047.792778.6.29.007400871.46906.1494282718...
# 1     8.4.13.5.7107.1.3.1.83378.85160090820978679507...
# 2     8.6.164.245568.6.95.8200738032.6711.2222200789...
# 3     8.2.311.726762.5.22.9217994636.8301.5241719335...
# 4     9.6.841.464467.4574.5.5.1.85.5681651901.673660...
# ...                                                 ...
# 2053  8.6.445.753144.8.62.3786901830.05650.243881648...
# 2054  5.4.805.860428.7.65.2439446130.59792.483177683...
# 2055  2.7.852.918558.9.58.881702658.21645.9393837632...
# 2056  6.7.971.555090.3485.1.3.2.96.3817363671.729992...
# 2057  0.3.433.532416.4.69.1338577813.321661.78291071...
#
#                                                   Paths  Contrast  \
# 0     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 1     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
# 2     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 3     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 4     ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
# ...                                                 ...       ...
# 2053  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 2054  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 2055  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...      -1.0
# 2056  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
# 2057  ['/nfs/MBSI/Osteoporosis/Head-CT/DICOM_extract...       0.0
#
#      ContrastBolusAgent
# 0
# 1
# 2
# 3            Anonymized
# 4
# ...                 ...
# 2053
# 2054
# 2055
# 2056
# 2057
#
# [2058 rows x 7 columns]

# %%
predictions_df[(predictions_df["Contrast"] == 1) & (predictions_df["ContrastBolusAgent"] == "Anonymized")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 predictions_df[predictions_df["Contrast"] == 1 and predictions_df["ContrastBolusAgent"] == "Anonymized"]
#
# File /opt/miniconda3/envs/osteoporosis_2/lib/python3.10/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
